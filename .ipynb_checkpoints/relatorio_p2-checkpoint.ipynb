# %% [markdown]
# # Projeto 2 - Ciência dos Dados
#
# João Otávio Gentil Palma

# %% [markdown]
# # Prevendo o rendimento médio de fazendas pelo Brasil
# ___
# ## Introdução
#
# ### O Objetivo
#
# O objetivo do projeto 2 de Ciência dos Dados é **prever**, por meio de algumas variáveis $features$, **uma variável $target$**. Em termos mais comuns, isso significa dizer que, com base em variáveis que explicam ou afetam um fenômeno, ou seja, que têm correlação com ele, vamos prever esse fenômeno, seja ele um número (variável quantitativa) ou classificação (variável qualitativa).
#
# ### Rendimento médio de uma plantação
#
# No caso do tema específico do projeto, vamos **prever o rendimento médio de uma safra (colheita)** com base em vários fatores que se correlacionam com o preço, como a localização, produto, área plantada, área colhida, quantidade produzida, valor_producao, entre outros.

# %%
import pandas as pd
import seaborn as sns

import numpy as np
from scipy.stats import norm, probplot
import statsmodels.api as sm
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

from pandas.plotting import scatter_matrix

from sklearn import tree

# %% [markdown]
# # Filtros
# Em seguida filtraremos o dataframe utilizado para trabalharmos com apenas as 'features' desejadas.

# %%
# Explorando df de lavouras temporarias

dados_temporario = pd.read_csv("dados_lavouras_temporario_na.csv")
dados_temporario = dados_temporario.drop(columns=['Unnamed: 0', 'id_municipio'])
dados_temporario = dados_temporario.dropna()
dados_temporario['Tipo'] = 'Temporário'
dados_temporario

# Explorando df de lavouras permanentes

dados_permanente = pd.read_csv("dados_lavouras_permanente_na.csv")
dados_permanente = dados_permanente.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'id_municipio'])
dados_permanente['Tipo'] = 'Permanente'
dados_permanente


# Concatenando ambas as planilhas
dados_lavouras = pd.concat([dados_permanente, dados_temporario], axis=0)
dados_lavouras = dados_lavouras.dropna()
dados_lavouras
# Out:
#           ano sigla_uf                 produto  area_plantada  area_colhida  \
# 0        2007       BA                   Manga           85.0          85.0
# 1        2007       BA  Sisal ou agave (fibra)           60.0          60.0
# 2        2007       BA            Coco-da-baía           19.0          15.0
# 3        2007       BA                Maracujá            3.0           3.0
# 4        2007       BA                   Limão            5.0           5.0
# ...       ...      ...                     ...            ...           ...
# 8444613  2018       MG                  Tomate            5.0           5.0
# 8444618  2018       MG                  Tomate            1.0           1.0
# 8444620  2018       MG        Feijão (em grão)           30.0          30.0
# 8444621  2018       MG         Sorgo (em grão)            3.0           3.0
# 8444630  2018       MG                Mandioca          140.0         140.0
#
#          quantidade_produzida  rendimento_medio  valor_producao  \
# 0                       340.0            4000.0            88.0
# 1                        60.0            1000.0            54.0
# 2                        75.0            5000.0            30.0
# 3                        45.0           15000.0             9.0
# 4                        78.0           15600.0            32.0
# ...                       ...               ...             ...
# 8444613                 290.0           58000.0           411.0
# 8444618                  35.0           35000.0            47.0
# 8444620                  24.0             800.0            72.0
# 8444621                   9.0            3000.0             3.0
# 8444630                1680.0           12000.0          1218.0
#
#          prop_area_plantada  prop_area_colhida  prop_valor_producao  \
# 0                     11.02              11.02                 8.55
# 1                      0.75               0.76                 0.28
# 2                     18.63              15.31                10.49
# 3                      0.51               0.51                 0.16
# 4                      0.11               0.12                 0.23
# ...                     ...                ...                  ...
# 8444613                0.03               0.03                 0.50
# 8444618                0.11               0.11                 0.77
# 8444620               10.27              10.27                 6.99
# 8444621                1.03               1.03                 0.29
# 8444630                7.06              19.94                51.79
#
#                Tipo
# 0        Permanente
# 1        Permanente
# 2        Permanente
# 3        Permanente
# 4        Permanente
# ...             ...
# 8444613  Temporário
# 8444618  Temporário
# 8444620  Temporário
# 8444621  Temporário
# 8444630  Temporário
#
# [1651186 rows x 12 columns]

# %%
#dados_lavouras['ano'].value_counts()

# %%
# Removendo as linhas dos anos 1994 ou antes, pois a moeda era diferente

dados_lavouras = dados_lavouras.drop(dados_lavouras[dados_lavouras.ano.isin([1991, 1992, 1989, 1993])].index).reset_index(drop=True)

# %% [markdown]
# Até o momento, foi feito um filtro nos dados da planilha para que ela fique masi prática e fácil de trabalhar
#
# Tirei anos anteriores a 1994, pois a moeda que circulava era diferente

# %%
dados_lavouras
# Out:
#           ano sigla_uf                 produto  area_plantada  area_colhida  \
# 0        2007       BA                   Manga           85.0          85.0
# 1        2007       BA  Sisal ou agave (fibra)           60.0          60.0
# 2        2007       BA            Coco-da-baía           19.0          15.0
# 3        2007       BA                Maracujá            3.0           3.0
# 4        2007       BA                   Limão            5.0           5.0
# ...       ...      ...                     ...            ...           ...
# 1650072  2018       MG                  Tomate            5.0           5.0
# 1650073  2018       MG                  Tomate            1.0           1.0
# 1650074  2018       MG        Feijão (em grão)           30.0          30.0
# 1650075  2018       MG         Sorgo (em grão)            3.0           3.0
# 1650076  2018       MG                Mandioca          140.0         140.0
#
#          quantidade_produzida  rendimento_medio  valor_producao  \
# 0                       340.0            4000.0            88.0
# 1                        60.0            1000.0            54.0
# 2                        75.0            5000.0            30.0
# 3                        45.0           15000.0             9.0
# 4                        78.0           15600.0            32.0
# ...                       ...               ...             ...
# 1650072                 290.0           58000.0           411.0
# 1650073                  35.0           35000.0            47.0
# 1650074                  24.0             800.0            72.0
# 1650075                   9.0            3000.0             3.0
# 1650076                1680.0           12000.0          1218.0
#
#          prop_area_plantada  prop_area_colhida  prop_valor_producao  \
# 0                     11.02              11.02                 8.55
# 1                      0.75               0.76                 0.28
# 2                     18.63              15.31                10.49
# 3                      0.51               0.51                 0.16
# 4                      0.11               0.12                 0.23
# ...                     ...                ...                  ...
# 1650072                0.03               0.03                 0.50
# 1650073                0.11               0.11                 0.77
# 1650074               10.27              10.27                 6.99
# 1650075                1.03               1.03                 0.29
# 1650076                7.06              19.94                51.79
#
#                Tipo
# 0        Permanente
# 1        Permanente
# 2        Permanente
# 3        Permanente
# 4        Permanente
# ...             ...
# 1650072  Temporário
# 1650073  Temporário
# 1650074  Temporário
# 1650075  Temporário
# 1650076  Temporário
#
# [1650077 rows x 12 columns]

# %%
# Analisando a relação entre as variáveis

# sns.pairplot(dados_lavouras, height=1.5);
dados_lavouras.corr()
# Out:
#                            ano  area_plantada  area_colhida  \
# ano                   1.000000       0.030341      0.030757
# area_plantada         0.030341       1.000000      0.999091
# area_colhida          0.030757       0.999091      1.000000
# quantidade_produzida  0.030241       0.388486      0.388909
# rendimento_medio     -0.110830      -0.011173     -0.010258
# valor_producao        0.100294       0.812540      0.814307
# prop_area_plantada    0.041741       0.207208      0.205157
# prop_area_colhida     0.042519       0.206351      0.205084
# prop_valor_producao   0.040893       0.189787      0.189369
#
#                       quantidade_produzida  rendimento_medio  valor_producao  \
# ano                               0.030241         -0.110830        0.100294
# area_plantada                     0.388486         -0.011173        0.812540
# area_colhida                      0.388909         -0.010258        0.814307
# quantidade_produzida              1.000000          0.207042        0.442953
# rendimento_medio                  0.207042          1.000000        0.034347
# valor_producao                    0.442953          0.034347        1.000000
# prop_area_plantada                0.190248         -0.042753        0.193109
# prop_area_colhida                 0.189675         -0.041857        0.192795
# prop_valor_producao               0.202889          0.070652        0.212513
#
#                       prop_area_plantada  prop_area_colhida  \
# ano                             0.041741           0.042519
# area_plantada                   0.207208           0.206351
# area_colhida                    0.205157           0.205084
# quantidade_produzida            0.190248           0.189675
# rendimento_medio               -0.042753          -0.041857
# valor_producao                  0.193109           0.192795
# prop_area_plantada              1.000000           0.994111
# prop_area_colhida               0.994111           1.000000
# prop_valor_producao             0.862252           0.869810
#
#                       prop_valor_producao
# ano                              0.040893
# area_plantada                    0.189787
# area_colhida                     0.189369
# quantidade_produzida             0.202889
# rendimento_medio                 0.070652
# valor_producao                   0.212513
# prop_area_plantada               0.862252
# prop_area_colhida                0.869810
# prop_valor_producao              1.000000

# %%
norte = ['AM', 'RR', 'AP', 'PA', 'TO', 'RO', 'AC']
nordeste = ['MA', 'PI', 'CE', 'RN', 'PE', 'PB', 'SE', 'AL', 'BA']
centro_oeste = ['MT', 'MS', 'GO']
sudeste = ['SP', 'RJ', 'ES', 'MG']
sul = ['PR', 'RS', 'SC']
def func_regiao(sigla):
    if sigla in norte:
        return 'Norte'
    elif sigla in nordeste:
        return 'Nordeste'
    elif sigla in centro_oeste:
        return 'Centro-oeste'
    elif sigla in sudeste:
        return 'Sudeste'
    else:
        return 'Sul'
        
dados_lavouras['regiao'] = dados_lavouras['sigla_uf'].apply(func_regiao)

# %%
dados_lavouras = dados_lavouras[['ano', 'sigla_uf','regiao', 'produto', 'area_plantada', 'area_colhida',
       'quantidade_produzida', 'rendimento_medio', 'valor_producao',
       'prop_area_plantada', 'prop_area_colhida', 'prop_valor_producao',
       'Tipo']]

#dados_lavouras.loc[dados_lavouras['regiao'] == 'Sudeste'].corr()

# %% [markdown]
# # Mudança de data frame
# Para que o trabalho seja mais prático e o pandas consiga trbalhar idem, foi necessário separar o df em regiões.
# Com o df filtrado da devida maneira, vamos trabalhar somente com a região sudeste.

# %%
dados_lavouras_sudeste = dados_lavouras.loc[dados_lavouras['regiao'] == 'Sudeste']

dados_lavouras_sudeste
# Out:
#           ano sigla_uf   regiao               produto  area_plantada  \
# 25       1998       RJ  Sudeste  Café (em grão) Total            1.0
# 45       2001       ES  Sudeste                Goiaba            1.0
# 46       2001       ES  Sudeste                 Manga            4.0
# 47       2001       ES  Sudeste              Maracujá            7.0
# 48       2001       ES  Sudeste                 Manga            2.0
# ...       ...      ...      ...                   ...            ...
# 1650072  2018       MG  Sudeste                Tomate            5.0
# 1650073  2018       MG  Sudeste                Tomate            1.0
# 1650074  2018       MG  Sudeste      Feijão (em grão)           30.0
# 1650075  2018       MG  Sudeste       Sorgo (em grão)            3.0
# 1650076  2018       MG  Sudeste              Mandioca          140.0
#
#          area_colhida  quantidade_produzida  rendimento_medio  valor_producao  \
# 25                1.0                   1.0            1000.0             3.0
# 45                1.0                  20.0           20000.0            14.0
# 46                4.0                  84.0           21000.0            42.0
# 47                7.0                 245.0           35000.0           121.0
# 48                2.0                  32.0           16000.0            16.0
# ...               ...                   ...               ...             ...
# 1650072           5.0                 290.0           58000.0           411.0
# 1650073           1.0                  35.0           35000.0            47.0
# 1650074          30.0                  24.0             800.0            72.0
# 1650075           3.0                   9.0            3000.0             3.0
# 1650076         140.0                1680.0           12000.0          1218.0
#
#          prop_area_plantada  prop_area_colhida  prop_valor_producao  \
# 25                     3.13               3.13                 1.96
# 45                     0.01               0.01                 0.10
# 46                     1.33               1.33                14.05
# 47                     0.06               0.06                 0.76
# 48                     0.01               0.01                 0.07
# ...                     ...                ...                  ...
# 1650072                0.03               0.03                 0.50
# 1650073                0.11               0.11                 0.77
# 1650074               10.27              10.27                 6.99
# 1650075                1.03               1.03                 0.29
# 1650076                7.06              19.94                51.79
#
#                Tipo
# 25       Permanente
# 45       Permanente
# 46       Permanente
# 47       Permanente
# 48       Permanente
# ...             ...
# 1650072  Temporário
# 1650073  Temporário
# 1650074  Temporário
# 1650075  Temporário
# 1650076  Temporário
#
# [436831 rows x 13 columns]

# %% [markdown]
# ## Dummy's
#
# Como as 'features' de bairro e tipo do quarto são strings utilizaremos a técnica de dummy's para tranformá-los em números

# %%
ano = dados_lavouras_sudeste['ano']
sigla_uf = dados_lavouras_sudeste['sigla_uf']
produto = dados_lavouras_sudeste['produto']
produto_dummy = pd.get_dummies(produto)
area_plantada = dados_lavouras_sudeste['area_plantada']
area_colhida = dados_lavouras_sudeste['area_colhida']
quantidade_produzida = dados_lavouras_sudeste['quantidade_produzida']
rendimento_medio = dados_lavouras_sudeste['rendimento_medio']
valor_producao = dados_lavouras_sudeste['valor_producao']
prop_area_plantada = dados_lavouras_sudeste['prop_area_plantada']
prop_area_colhida = dados_lavouras_sudeste['prop_area_colhida']
prop_valor_producao = dados_lavouras_sudeste['prop_valor_producao']
tipo = dados_lavouras_sudeste['Tipo']
tipo_dummy = pd.get_dummies(tipo)

# %% [markdown]
# # Análise exploratória

# %%
corr = dados_lavouras_sudeste.corr()
corr
# Out:
#                            ano  area_plantada  area_colhida  \
# ano                   1.000000       0.043932      0.043413
# area_plantada         0.043932       1.000000      0.999181
# area_colhida          0.043413       0.999181      1.000000
# quantidade_produzida  0.035176       0.736261      0.736346
# rendimento_medio     -0.110303       0.105996      0.106227
# valor_producao        0.151149       0.768746      0.769519
# prop_area_plantada    0.071284       0.354975      0.354365
# prop_area_colhida     0.071434       0.354728      0.354633
# prop_valor_producao   0.068816       0.336166      0.336371
#
#                       quantidade_produzida  rendimento_medio  valor_producao  \
# ano                               0.035176         -0.110303        0.151149
# area_plantada                     0.736261          0.105996        0.768746
# area_colhida                      0.736346          0.106227        0.769519
# quantidade_produzida              1.000000          0.251422        0.610241
# rendimento_medio                  0.251422          1.000000        0.107942
# valor_producao                    0.610241          0.107942        1.000000
# prop_area_plantada                0.251133         -0.003588        0.339656
# prop_area_colhida                 0.251225         -0.002434        0.339909
# prop_valor_producao               0.265859          0.112955        0.362377
#
#                       prop_area_plantada  prop_area_colhida  \
# ano                             0.071284           0.071434
# area_plantada                   0.354975           0.354728
# area_colhida                    0.354365           0.354633
# quantidade_produzida            0.251133           0.251225
# rendimento_medio               -0.003588          -0.002434
# valor_producao                  0.339656           0.339909
# prop_area_plantada              1.000000           0.998515
# prop_area_colhida               0.998515           1.000000
# prop_valor_producao             0.896487           0.899215
#
#                       prop_valor_producao
# ano                              0.068816
# area_plantada                    0.336166
# area_colhida                     0.336371
# quantidade_produzida             0.265859
# rendimento_medio                 0.112955
# valor_producao                   0.362377
# prop_area_plantada               0.896487
# prop_area_colhida                0.899215
# prop_valor_producao              1.000000

# %% [markdown]
# # Gráficos de correlações

# %%
plt.matshow(dados_lavouras_sudeste.corr())
plt.show()

# %%
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_92652_row0_col0, #T_92652_row1_col1, #T_92652_row1_col2, #T_92652_row2_col1, #T_92652_row2_col2, #T_92652_row3_col3, #T_92652_row4_col4, #T_92652_row5_col5, #T_92652_row6_col6, #T_92652_row6_col7, #T_92652_row7_col6, #T_92652_row7_col7, #T_92652_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_92652_row0_col1, #T_92652_row0_col2, #T_92652_row1_col0, #T_92652_row2_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_92652_row0_col3, #T_92652_row3_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_92652_row0_col4, #T_92652_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_92652_row0_col5, #T_92652_row5_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_92652_row0_col6, #T_92652_row0_col7, #T_92652_row0_col8, #T_92652_row6_col0, #T_92652_row7_col0, #T_92652_row8_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_92652_row1_col3, #T_92652_row2_col3, #T_92652_row3_col1, #T_92652_row3_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_92652_row1_col4, #T_92652_row2_col4, #T_92652_row4_col1, #T_92652_row4_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_92652_row1_col5, #T_92652_row2_col5, #T_92652_row5_col1, #T_92652_row5_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_92652_row1_col6, #T_92652_row1_col7, #T_92652_row2_col6, #T_92652_row2_col7, #T_92652_row6_col1, #T_92652_row6_col2, #T_92652_row7_col1, #T_92652_row7_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_92652_row1_col8, #T_92652_row2_col8, #T_92652_row8_col1, #T_92652_row8_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_92652_row3_col4, #T_92652_row3_col6, #T_92652_row3_col7, #T_92652_row4_col3, #T_92652_row6_col3, #T_92652_row7_col3 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_92652_row3_col5, #T_92652_row5_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_92652_row3_col8, #T_92652_row8_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_92652_row4_col5, #T_92652_row5_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_92652_row4_col6, #T_92652_row4_col7, #T_92652_row6_col4, #T_92652_row7_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_92652_row4_col8, #T_92652_row8_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_92652_row5_col6, #T_92652_row5_col7, #T_92652_row6_col5, #T_92652_row7_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_92652_row5_col8, #T_92652_row8_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_92652_row6_col8, #T_92652_row7_col8, #T_92652_row8_col6, #T_92652_row8_col7 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_92652">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92652_level0_col0" class="col_heading level0 col0" >ano</th>
#       <th id="T_92652_level0_col1" class="col_heading level0 col1" >area_plantada</th>
#       <th id="T_92652_level0_col2" class="col_heading level0 col2" >area_colhida</th>
#       <th id="T_92652_level0_col3" class="col_heading level0 col3" >quantidade_produzida</th>
#       <th id="T_92652_level0_col4" class="col_heading level0 col4" >rendimento_medio</th>
#       <th id="T_92652_level0_col5" class="col_heading level0 col5" >valor_producao</th>
#       <th id="T_92652_level0_col6" class="col_heading level0 col6" >prop_area_plantada</th>
#       <th id="T_92652_level0_col7" class="col_heading level0 col7" >prop_area_colhida</th>
#       <th id="T_92652_level0_col8" class="col_heading level0 col8" >prop_valor_producao</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92652_level0_row0" class="row_heading level0 row0" >ano</th>
#       <td id="T_92652_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_92652_row0_col1" class="data row0 col1" >0.043932</td>
#       <td id="T_92652_row0_col2" class="data row0 col2" >0.043413</td>
#       <td id="T_92652_row0_col3" class="data row0 col3" >0.035176</td>
#       <td id="T_92652_row0_col4" class="data row0 col4" >-0.110303</td>
#       <td id="T_92652_row0_col5" class="data row0 col5" >0.151149</td>
#       <td id="T_92652_row0_col6" class="data row0 col6" >0.071284</td>
#       <td id="T_92652_row0_col7" class="data row0 col7" >0.071434</td>
#       <td id="T_92652_row0_col8" class="data row0 col8" >0.068816</td>
#     </tr>
#     <tr>
#       <th id="T_92652_level0_row1" class="row_heading level0 row1" >area_plantada</th>
#       <td id="T_92652_row1_col0" class="data row1 col0" >0.043932</td>
#       <td id="T_92652_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_92652_row1_col2" class="data row1 col2" >0.999181</td>
#       <td id="T_92652_row1_col3" class="data row1 col3" >0.736261</td>
#       <td id="T_92652_row1_col4" class="data row1 col4" >0.105996</td>
#       <td id="T_92652_row1_col5" class="data row1 col5" >0.768746</td>
#       <td id="T_92652_row1_col6" class="data row1 col6" >0.354975</td>
#       <td id="T_92652_row1_col7" class="data row1 col7" >0.354728</td>
#       <td id="T_92652_row1_col8" class="data row1 col8" >0.336166</td>
#     </tr>
#     <tr>
#       <th id="T_92652_level0_row2" class="row_heading level0 row2" >area_colhida</th>
#       <td id="T_92652_row2_col0" class="data row2 col0" >0.043413</td>
#       <td id="T_92652_row2_col1" class="data row2 col1" >0.999181</td>
#       <td id="T_92652_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_92652_row2_col3" class="data row2 col3" >0.736346</td>
#       <td id="T_92652_row2_col4" class="data row2 col4" >0.106227</td>
#       <td id="T_92652_row2_col5" class="data row2 col5" >0.769519</td>
#       <td id="T_92652_row2_col6" class="data row2 col6" >0.354365</td>
#       <td id="T_92652_row2_col7" class="data row2 col7" >0.354633</td>
#       <td id="T_92652_row2_col8" class="data row2 col8" >0.336371</td>
#     </tr>
#     <tr>
#       <th id="T_92652_level0_row3" class="row_heading level0 row3" >quantidade_produzida</th>
#       <td id="T_92652_row3_col0" class="data row3 col0" >0.035176</td>
#       <td id="T_92652_row3_col1" class="data row3 col1" >0.736261</td>
#       <td id="T_92652_row3_col2" class="data row3 col2" >0.736346</td>
#       <td id="T_92652_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_92652_row3_col4" class="data row3 col4" >0.251422</td>
#       <td id="T_92652_row3_col5" class="data row3 col5" >0.610241</td>
#       <td id="T_92652_row3_col6" class="data row3 col6" >0.251133</td>
#       <td id="T_92652_row3_col7" class="data row3 col7" >0.251225</td>
#       <td id="T_92652_row3_col8" class="data row3 col8" >0.265859</td>
#     </tr>
#     <tr>
#       <th id="T_92652_level0_row4" class="row_heading level0 row4" >rendimento_medio</th>
#       <td id="T_92652_row4_col0" class="data row4 col0" >-0.110303</td>
#       <td id="T_92652_row4_col1" class="data row4 col1" >0.105996</td>
#       <td id="T_92652_row4_col2" class="data row4 col2" >0.106227</td>
#       <td id="T_92652_row4_col3" class="data row4 col3" >0.251422</td>
#       <td id="T_92652_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_92652_row4_col5" class="data row4 col5" >0.107942</td>
#       <td id="T_92652_row4_col6" class="data row4 col6" >-0.003588</td>
#       <td id="T_92652_row4_col7" class="data row4 col7" >-0.002434</td>
#       <td id="T_92652_row4_col8" class="data row4 col8" >0.112955</td>
#     </tr>
#     <tr>
#       <th id="T_92652_level0_row5" class="row_heading level0 row5" >valor_producao</th>
#       <td id="T_92652_row5_col0" class="data row5 col0" >0.151149</td>
#       <td id="T_92652_row5_col1" class="data row5 col1" >0.768746</td>
#       <td id="T_92652_row5_col2" class="data row5 col2" >0.769519</td>
#       <td id="T_92652_row5_col3" class="data row5 col3" >0.610241</td>
#       <td id="T_92652_row5_col4" class="data row5 col4" >0.107942</td>
#       <td id="T_92652_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_92652_row5_col6" class="data row5 col6" >0.339656</td>
#       <td id="T_92652_row5_col7" class="data row5 col7" >0.339909</td>
#       <td id="T_92652_row5_col8" class="d

# %%
dados_y = dados_lavouras_sudeste['rendimento_medio']
dados_x = dados_lavouras_sudeste[['area_plantada', 'area_colhida', 'quantidade_produzida', 'valor_producao', 'prop_area_plantada', 'prop_area_colhida']]

# %%
dados_y.describe()
# Out:
# count    436831.000000
# mean      18207.173790
# std       29086.807198
# min           3.000000
# 25%        1800.000000
# 50%        7176.000000
# 75%       21000.000000
# max      850000.000000
# Name: rendimento_medio, dtype: float64

# %%
#sns.pairplot(dados_lavouras_sudeste, x_vars = ['area_colhida'], y_vars = ['rendimento_medio'], hue='produto');

sns.pairplot(dados_lavouras_sudeste.head(100), height=1.5)

# %%
def regress(Y,X):
    '''
    Y: coluna do DataFrame utilizada como variável resposta (TARGET)
    X: coluna(s) do DataFrame utilizadas como variável(is) explicativas (FEATURES)
    '''
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    
    return results

results = regress(dados_x,dados_y)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       rendimento_medio   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     6265.
# Date:                Tue, 23 May 2023   Prob (F-statistic):               0.00
# Time:                        15:38:22   Log-Likelihood:            -5.0916e+06
# No. Observations:              436831   AIC:                         1.018e+07
# Df Residuals:                  436824   BIC:                         1.018e+07
# Df Model:                           6
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1.876e+04     51.580    363.771      0.000    1.87e+04    1.89e+04
# area_plantada           -0.5898      0.325     -1.816      0.069      -1.226       0.047
# area_colhida            -0.9806      0.326     -3.004      0.003      -1.620      -0.341
# quantidade_produzida     0.0567      0.000    173.558      0.000       0.056       0.057
# valor_producao           0.0655      0.005     13.673      0.000       0.056       0.075
# prop_area_plantada    -418.2943     28.579    -14.636      0.000    -474.309    -362.279
# prop_area_colhida      371.7959     28.580     13.009      0.000     315.780     427.811
# ==============================================================================
# Omnibus:                   433538.412   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         44911732.607
# Skew:                           4.673   Prob(JB):                         0.00
# Kurtosis:                      51.787   Cond. No.                     2.37e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Interpretando os dados acima, nota-se que a regressão utilizada não foi a mais eficaz. Isso é evidente quando o valor do R-squared é distante de 1.

# %%
X_train, X_test, y_train, y_test = train_test_split(dados_x, dados_y, test_size=0.4, random_state=0)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
import sklearn.metrics

regressor = DecisionTreeRegressor(random_state=0)
cross_val_score(regressor, dados_x, dados_y, cv=10, scoring='neg_mean_absolute_error')
# Out:
# array([-185.41821071, -199.91210921, -194.04931247, -190.94917741,
#        -138.9107166 ,  -80.25912636,  -77.46927104,  -79.40518203,
#         -80.23214218,  -81.93624331])

# %%
cross_val_score(regressor, dados_x, dados_y, cv=10, scoring='r2')
# Out:
# array([0.99642379, 0.99304142, 0.99175453, 0.99296975, 0.99357751,
#        0.99938726, 0.99947155, 0.99947149, 0.99946006, 0.99929902])

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(dados_x, dados_y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20984\2808746975.py in <module>
#       2
#       3 clf = tree.DecisionTreeClassifier()
# ----> 4 clf = clf.fit(dados_x, dados_y)
#
# ~\OneDrive\Aplicativos\programas\anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~\OneDrive\Aplicativos\programas\anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._add_node()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._resize_c()
#
# sklearn\tree\_utils.pyx in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 11942232064 bytes

# %%
clf = tree.DecisionTreeRegressor()
clf = clf.fit(dados_x, dados_y)
clf.predict([[5, 5]])
# Out:
# C:\Users\joaoo\OneDrive\Aplicativos\programas\anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20984\144572279.py in <module>
#       1 clf = tree.DecisionTreeRegressor()
#       2 clf = clf.fit(dados_x, dados_y)
# ----> 3 clf.predict([[5, 5]])
#
# ~\OneDrive\Aplicativos\programas\anaconda\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     465         """
#     466         check_is_fitted(self)
# --> 467         X = self._validate_X_predict(X, check_input)
#     468         proba = self.tree_.predict(X)
#     469         n_samples = X.shape[0]
#
# ~\OneDrive\Aplicativos\programas\anaconda\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     431         """Validate the training data on predict (probabilities)."""
#     432         if check_input:
# --> 433             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     434             if issparse(X) and (
#     435                 X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#
# ~\OneDrive\Aplicativos\programas\anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     583
#     584         if not no_val_X and check_params.get("ensure_2d", True):
# --> 585             self._check_n_features(X, reset=reset)
#     586
#     587         return out
#
# ~\OneDrive\Aplicativos\programas\anaconda\lib\site-packages\sklearn\base.py in _check_n_features(self, X, reset)
#     398
#     399         if n_features != self.n_features_in_:
# --> 400             raise ValueError(
#     401                 f"X has {n_features} features, but {self.__class__.__name__} "
#     402                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 2 features, but DecisionTreeRegressor is expecting 6 features as input.

# %%
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_absolute_percentage_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'top_k_accuracy',
#  'v_measure_score']
